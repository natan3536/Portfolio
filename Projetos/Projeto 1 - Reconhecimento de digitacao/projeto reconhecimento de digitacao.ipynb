# %% [markdown]
# ### Carregando as bibliotecas necessária

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv2D, Lambda, MaxPool2D ,AveragePooling2D
from keras.layers import Dense, Dropout, Flatten 
from keras.layers import BatchNormalization

from keras.preprocessing.image import ImageDataGenerator

from keras.utils.np_utils import to_categorical

# %% [markdown]
# Neste projeto iremos usar a GPU para fazer o processamento, então a seguir iremos definir para o tensoflow usar a gpu e depois iremos limitar a memoria vram da gpu para evitar problemas.

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
gpu_opts = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=0.4)
Sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(gpu_options=gpu_opts))

# %% [markdown]
# ### Carregaando conjunto de dados

# %%
train,test,sub = pd.read_csv('train.csv'), pd.read_csv('test.csv'),pd.read_csv('sample_submission.csv')

# %%
x_train,y_train=train.drop('label',axis=1),train['label']

# %% [markdown]
# Vamos ajusta a escala para ficar entre 0 e 1 e depois vamos estruturar o conjunto de dados

# %%
x_train/=255.0
test/=255.0

# %%
x_train = x_train.values.reshape(-1,28,28,1)
test = test.values.reshape(-1,28,28,1)

# %% [markdown]
# A seguir vamos plotar as imagens com suas respectivas categorias

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(y_train[i])
plt.show()

# %%
y_train = to_categorical(y_train, num_classes = 10)

# %% [markdown]
# Apos criar as categorias na variável resposta, vamos separar o conjunto de dados em treinamento e teste, assim fazendo a validação do modelo.

# %%
X_train, X_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.1, shuffle=True,random_state=42)

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((37800, 28, 28, 1), (4200, 28, 28, 1), (37800, 10), (4200, 10))

# %% [markdown]
# Adicionando as camadas no modelo.
#
# O modelo que será usado é o modelo convolucional, este modelo apresenta bons resultados em analisar imagens.

# %%
model = Sequential()

model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', activation ='relu', input_shape = (28,28,1)))
model.add(Conv2D(filters = 158, kernel_size = (5,5), activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters = 158, kernel_size = (3,3), activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (2,2), activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Conv2D(filters = 10, kernel_size = (2,2),padding = 'Same' , activation ='relu'))
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(256, activation = "relu"))
model.add(Dense(256, activation = "relu"))
model.add(BatchNormalization())
#model.add(Dropout(0.25))

model.add(Dense(10, activation = "softmax"))
    
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 64)        1664
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 158)       252958
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 158)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 158)       224834
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 158)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 64)          40512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 2, 2, 10)          2570
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2, 2, 10)          40
# _________________________________________________________________
# flatten (Flatten)            (None, 40)                0
# _________________________________________________________________
# dense (Dense)                (None, 256)               10496
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 602,460
# Trainable params: 601,928
# Non-trainable params: 532
# _________________________________________________________________

# %% [markdown]
# A seguir vamos definir alguns parâmetros importante e vamos gerar o modelo.

# %%
rp = keras.callbacks.ReduceLROnPlateau(
        monitor="val_acc",
        factor=0.2,
        patience=3,
        verbose=1,
        mode="max",
        min_lr=0.000001,
     )
history = model.fit(X_train, y_train, steps_per_epoch=len(X_train)/100, 
                    epochs=50, validation_data=(X_val, y_val), callbacks=[rp])
# Out:
# Epoch 1/50
# 378/378 [==============================] - 30s 50ms/step - loss: 0.1562 - accuracy: 0.9510 - val_loss: 0.4321 - val_accuracy: 0.8676
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 2/50
# 378/378 [==============================] - 18s 48ms/step - loss: 0.0486 - accuracy: 0.9844 - val_loss: 0.4303 - val_accuracy: 0.8762
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 3/50
# 378/378 [==============================] - 18s 49ms/step - loss: 0.0342 - accuracy: 0.9892 - val_loss: 0.0585 - val_accuracy: 0.9817
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 4/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0285 - accuracy: 0.9911 - val_loss: 0.0389 - val_accuracy: 0.9890
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 5/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0219 - accuracy: 0.9928 - val_loss: 0.1774 - val_accuracy: 0.9488
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 6/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0439 - val_accuracy: 0.9867
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 7/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0186 - accuracy: 0.9940 - val_loss: 0.1051 - val_accuracy: 0.9738
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 8/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0146 - accuracy: 0.9956 - val_loss: 0.0742 - val_accuracy: 0.9793
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 9/50
# 378/378 [==============================] - 19s 50ms/step - loss: 0.0126 - accuracy: 0.9961 - val_loss: 0.0369 - val_accuracy: 0.9900
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 10/50
# 378/378 [==============================] - 19s 50ms/step - loss: 0.0133 - accuracy: 0.9956 - val_loss: 0.1376 - val_accuracy: 0.9652
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 11/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0114 - accuracy: 0.9963 - val_loss: 0.0413 - val_accuracy: 0.9874
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 12/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.0492 - val_accuracy: 0.9864
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 13/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.0550 - val_accuracy: 0.9838
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 14/50
# 378/378 [==============================] - 19s 50ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.0916 - val_accuracy: 0.9750
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 15/50
# 378/378 [==============================] - 19s 50ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0704 - val_accuracy: 0.9836
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 16/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0430 - val_accuracy: 0.9886
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 17/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0387 - val_accuracy: 0.9893
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 18/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0298 - val_accuracy: 0.9914
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 19/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0455 - val_accuracy: 0.9890
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 20/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0782 - val_accuracy: 0.9833
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 21/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0375 - val_accuracy: 0.9888
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 22/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0641 - val_accuracy: 0.9840
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 23/50
# 378/378 [==============================] - 19s 50ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0319 - val_accuracy: 0.9924
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 24/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0485 - val_accuracy: 0.9888
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 25/50
# 378/378 [==============================] - 19s 50ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.1426 - val_accuracy: 0.9731
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 26/50
# 378/378 [==============================] - 19s 50ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0428 - val_accuracy: 0.9905
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 27/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0364 - val_accuracy: 0.9921
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 28/50
# 378/378 [==============================] - 19s 50ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 0.0399 - val_accuracy: 0.9910
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 29/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0565 - val_accuracy: 0.9871
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 30/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0438 - val_accuracy: 0.9898
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 31/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.0517 - val_accuracy: 0.9895
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 32/50
# 378/378 [==============================] - 19s 50ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0686 - val_accuracy: 0.9855
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 33/50
# 378/378 [==============================] - 19s 50ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0773 - val_accuracy: 0.9845
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 34/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0767 - val_accuracy: 0.9860
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 35/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.0574 - val_accuracy: 0.9857
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 36/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0570 - val_accuracy: 0.9876
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 37/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0378 - val_accuracy: 0.9907
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 38/50
# 378/378 [==============================] - 19s 49ms/step - loss: 6.3407e-04 - accuracy: 0.9998 - val_loss: 0.0564 - val_accuracy: 0.9895
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 39/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.1194 - val_accuracy: 0.9764
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 40/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0412 - val_accuracy: 0.9912
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 41/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0448 - val_accuracy: 0.9912
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 42/50
# 378/378 [==============================] - 19s 50ms/step - loss: 5.9798e-04 - accuracy: 0.9998 - val_loss: 0.0580 - val_accuracy: 0.9898
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 43/50
# 378/378 [==============================] - 19s 49ms/step - loss: 9.3357e-04 - accuracy: 0.9997 - val_loss: 0.0432 - val_accuracy: 0.9902
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 44/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0085 - accuracy: 0.9976 - val_loss: 0.0573 - val_accuracy: 0.9857
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 45/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0383 - val_accuracy: 0.9921
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 46/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0459 - val_accuracy: 0.9898
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 47/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0040 - accuracy: 0.9985 - val_loss: 0.0646 - val_accuracy: 0.9890
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 48/50
# 378/378 [==============================] - 19s 49ms/step - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.0325 - val_accuracy: 0.9929
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 49/50
# 378/378 [==============================] - 18s 48ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0443 - val_accuracy: 0.9907
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 50/50
# 378/378 [==============================] - 18s 48ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0615 - val_accuracy: 0.9886
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr

# %% [markdown]
# #### -------

# %% [markdown]
# Com o modelo criado vamos usar o conjunto de teste que o kaggle oferece e vamos fazer a previsão para aplicar no site e verificar a acurácia obtida.

# %%
X_test = np.array(test)
X_test = X_test.reshape((X_test.shape[0], 28, 28, 1))
Y_test = model.predict(X_test)

# %%
Y_test = np.argmax(Y_test, axis=1)
sub['Label']=Y_test
sub.head(10)
# Out:
#    ImageId  Label
# 0        1      2
# 1        2      0
# 2        3      9
# 3        4      0
# 4        5      3
# 5        6      7
# 6        7      0
# 7        8      3
# 8        9      0
# 9       10      3

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_test[i], cmap=plt.cm.binary)
    plt.xlabel(Y_test[i])
plt.show()

# %% [markdown]
# Com as previsões acima note que o modelo conseguir prever de forma assertiva todos os números na imagem anterior, com as previsões feita vamos salvar e enviar para o kaggle para saber a acurácia desse modelo no conjunto de teste. No Kaggle este modelo obteve uma acurácia de 0.99117, este resultado é muito bom pois mostra que o modelo é bem ajustado e evita o overfitting.

# %%
sub.to_csv('submission.csv', index=False)
